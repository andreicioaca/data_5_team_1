# %%
# !pip install afinn
from afinn import Afinn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: afinn in /usr/local/lib/python3.9/dist-packages (0.1)

# %%
import pandas as pd
import numpy as np

# %%
data_reviews = pd.read_csv('/content/cleaned_playstore_reviews.csv')
data_apps = pd.read_csv('/content/cleaned_playstore.csv')

# %%
data_apps.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver', 'Content Rating new'],
#       dtype='object')

# %%
data_reviews.sort_values('App')
# Out:
#      Unnamed: 0                                                App  \
# 0             0                              10 Best Foods for You
# 1             1                   104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2             2                                               11st
# 3             3                         1800 Contacts - Lens Store
# 4             4                    1LINE – One Line with One Touch
# ..          ...                                                ...
# 636         636                      Hotels Combined - Cheap deals
# 637         637  Hotels.com: Book Hotel Rooms & Find Vacation D...
# 638         638     Hotspot Shield Free VPN Proxy & Wi-Fi Security
# 639         639                                            Hotstar
# 640         640                     Housing-Real Estate & Property
#
#                                      Translated_Review Sentiment  \
# 0    i like eat delicious food thats im cooking foo...  Positive
# 1                                                great  Positive
# 2                             horrible id verification  Negative
# 3    great hassle free way order contacts got call ...  Positive
# 4    gets 1 theres ad every single level restart fr...  Negative
# ..                                                 ...       ...
# 636  totally unimpressed we booking hotels vietnam ...  Negative
# 637  bookings stopped showing app helpline useless ...  Positive
# 638        7 days free trial asking credit card stupid  Negative
# 639                                            running   Neutral
# 640  incorrect listings the agents show property di...  Negative
#
#      Sentiment_Polarity  Sentiment_Subjectivity
# 0              1.000000                0.533333
# 1              0.800000                0.750000
# 2             -1.000000                1.000000
# 3              0.600000                0.775000
# 4             -0.157143                0.704762
# ..                  ...                     ...
# 636           -0.083333                0.427778
# 637            0.291667                0.566667
# 638           -0.300000                0.900000
# 639            0.000000                0.000000
# 640           -0.025000                0.125000
#
# [641 rows x 6 columns]

# %%
data_apps['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
#sklearn kostly used for data science
#preprocessingis used for data cleaning and transforming
#labelencoder is transform categorical values into numerical 
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

le.fit(data_apps['Content Rating'].unique())

data_apps['Content Rating new'] = le.transform( data_apps['Content Rating']  )

# %%
data_apps.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating   Reviews          Size    Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1     159.0  1.900000e+07     10000.0  Free    0.0
# 1  ART_AND_DESIGN     3.9     967.0  1.400000e+07    500000.0  Free    0.0
# 2  ART_AND_DESIGN     4.7   87510.0  8.700000e+06   5000000.0  Free    0.0
# 3  ART_AND_DESIGN     4.5  215644.0  2.500000e+07  50000000.0  Free    0.0
# 4  ART_AND_DESIGN     4.3     967.0  2.800000e+06    100000.0  Free    0.0
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design   2018-01-07               1.0.0
# 1       Everyone  Art & Design;Pretend Play   2018-01-15               2.0.0
# 2       Everyone               Art & Design   2018-08-01               1.2.4
# 3           Teen               Art & Design   2018-06-08  Varies with device
# 4       Everyone    Art & Design;Creativity   2018-06-20                 1.1
#
#     Android Ver  Content Rating new
# 0  4.0.3 and up                   1
# 1  4.0.3 and up                   1
# 2  4.0.3 and up                   1
# 3    4.2 and up                   4
# 4    4.4 and up                   1

# %% [markdown]
# ### Week4 Task1

# %%
data_apps['Content Rating new'].corr(data_apps['Price'])
# Out:
# -0.014487939922676335

# %%
import seaborn as sns
corr = data_apps[['Content Rating new','Price']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Week4 Task2

# %%
data_reviews.head(2)
# Out:
#    Unnamed: 0                               App  \
# 0           0             10 Best Foods for You
# 1           1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
#
#                                    Translated_Review Sentiment  \
# 0  I like eat delicious food. That's I'm cooking ...  Positive
# 1                                              Great  Positive
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0                 1.0                0.533333
# 1                 0.8                0.750000

# %%
data_n = pd.read_excel('/content/n.xlsx')

# %%
data_p = pd.read_excel('/content/p.xlsx')

# %%
data_p[:5]
# Out:
#        abound
# 0     abounds
# 1   abundance
# 2    abundant
# 3  accessable
# 4  accessible

# %%
data_n[:5]
# Out:
#         faced
# 0       faces
# 1    abnormal
# 2     abolish
# 3  abominable
# 4  abominably

# %%
data_reviews['Translated_Review'] = data_reviews.Translated_Review.apply(str.lower)
data_reviews.head(5)
# Out:
#    Unnamed: 0                               App  \
# 0           0             10 Best Foods for You
# 1           1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2           2                              11st
# 3           3        1800 Contacts - Lens Store
# 4           4   1LINE – One Line with One Touch
#
#                                    Translated_Review Sentiment  \
# 0  i like eat delicious food thats im cooking foo...  Positive
# 1                                              great  Positive
# 2                           horrible id verification  Negative
# 3  great hassle free way order contacts got call ...  Positive
# 4  gets 1 theres ad every single level restart fr...  Negative
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0            1.000000                0.533333
# 1            0.800000                0.750000
# 2           -1.000000                1.000000
# 3            0.600000                0.775000
# 4           -0.157143                0.704762

# %%
data_reviews.describe()
# Out:
#        Unnamed: 0  Sentiment_Polarity  Sentiment_Subjectivity
# count  641.000000          641.000000              641.000000
# mean   320.000000            0.160982                0.497001
# std    185.185043            0.297465                0.213921
# min      0.000000           -1.000000                0.000000
# 25%    160.000000            0.000000                0.400000
# 50%    320.000000            0.151515                0.501852
# 75%    480.000000            0.328333                0.614626
# max    640.000000            1.000000                1.000000

# %% [markdown]
# ###### Cleaning a little

# %%
import string
def string_clean(sent):
 return sent.translate(str.maketrans('','',string.punctuation))

# %%
data_reviews['Translated_Review'] = data_reviews.Translated_Review.apply(string_clean)
data_reviews.head(10)
# Out:
#    Unnamed: 0                                               App  \
# 0           0                             10 Best Foods for You
# 1           1                  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2           2                                              11st
# 3           3                        1800 Contacts - Lens Store
# 4           4                   1LINE – One Line with One Touch
# 5           5  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif
# 6           6                      21-Day Meditation Experience
# 7           7               2Date Dating App, Love and matching
# 8           8                       2GIS: directory & navigator
# 9           9                                         2RedBeans
#
#                                    Translated_Review Sentiment  \
# 0  i like eat delicious food thats im cooking foo...  Positive
# 1                                              great  Positive
# 2                           horrible id verification  Negative
# 3  great hassle free way order contacts got call ...  Positive
# 4  gets 1 theres ad every single level restart fr...  Negative
# 5  like the old version better where backspace is...  Positive
# 6  terrible not userfriendly like original app pl...  Negative
# 7  this good dating app i love much this lot chin...  Positive
# 8  thanks lot excellent map 2gis i love it like m...  Positive
# 9         what waiting for join platform thank later   Neutral
#
#    Sentiment_Polarity  Sentiment_Subjectivity
# 0            1.000000                0.533333
# 1            0.800000                0.750000
# 2           -1.000000                1.000000
# 3            0.600000                0.775000
# 4           -0.157143                0.704762
# 5            0.300000                0.350000
# 6           -0.265625                0.875000
# 7            0.250980                0.532773
# 8            0.475000                0.500000
# 9            0.000000                0.000000

# %% [markdown]
# ##### Sentiments analysis using n and p files

# %%
a = Counter('data_n')
a = Counter

# %%
b = Counter('faiza')
b
# Out:
# Counter({'f': 1, 'a': 2, 'i': 1, 'z': 1})

# %%
a+b
# Out:
# Counter({'a': 3,
#          'r': 1,
#          'i': 3,
#          's': 1,
#          't': 1,
#          'd': 1,
#          'e': 1,
#          'f': 1,
#          'z': 1})

# %%
from collections import Counter
n = Counter ( list(data_n.faced) ) 
p = Counter ( list(data_p.abound) ) 

def sentiment_func(sent):
  c_sent = Counter(sent.split(' '))

  tot_n = n + c_sent
  tot_p = p + c_sent

  duplicates_n = Counter({k: c for k, c in tot_n.items() if c > 1})
  res_n = sum(duplicates_n.values()  )

  duplicates_p = Counter({k: c for k, c in tot_p.items() if c > 1})
  res_p = sum(duplicates_p.values()  )

  return (res_p - res_n) * 3

# %%
df['np_sentiments'] = data_reviews.Translated_Review.apply(sentiment_func)

# %% [markdown]
# ##### Sentiment analysis using Afinn library

# %%
afinn = Afinn()
afinn.score('ugly')
# Out:
# -3.0

# %%
df = data_reviews[['App','Translated_Review','Sentiment_Polarity']]

# %%
df['afinn_sentiments'] = data_reviews.Translated_Review.apply( Afinn().score)
# Out:
# <ipython-input-64-cf98520b560a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['np_sentiments'] = data_reviews.Translated_Review.apply(sentiment_func)
# <ipython-input-64-cf98520b560a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['afinn_sentiments'] = data_reviews.Translated_Review.apply( Afinn().score)

# %%
df.sort_values(['App']).head(4)
# Out:
#                                 App  \
# 0             10 Best Foods for You
# 1  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2                              11st
# 3        1800 Contacts - Lens Store
#
#                                    Translated_Review  Sentiment_Polarity  \
# 0  i like eat delicious food thats im cooking foo...                 1.0
# 1                                              great                 0.8
# 2                           horrible id verification                -1.0
# 3  great hassle free way order contacts got call ...                 0.6
#
#    np_sentiments  afinn_sentiments
# 0             15              13.0
# 1              6               3.0
# 2             -6              -3.0
# 3              6               4.0

# %% [markdown]
# ### Week4 Task3

# %%
#we joined two datasets and only rows that are common in both are displayed
data_merged = pd.merge(df, data_apps, how='inner', on='App')

# %%
data_merged.head()
# Out:
#                                                 App  \
# 0                             10 Best Foods for You
# 1                                              11st
# 2                        1800 Contacts - Lens Store
# 3                   1LINE – One Line with One Touch
# 4  2018Emoji Keyboard 😂 Emoticons Lite -sticker&gif
#
#                                    Translated_Review  Sentiment_Polarity  \
# 0  i like eat delicious food thats im cooking foo...            1.000000
# 1                           horrible id verification           -1.000000
# 2  great hassle free way order contacts got call ...            0.600000
# 3  gets 1 theres ad every single level restart fr...           -0.157143
# 4  like the old version better where backspace is...            0.300000
#
#    np_sentiments  afinn_sentiments  Unnamed: 0            Category  Rating  \
# 0             15              13.0        1142  HEALTH_AND_FITNESS     4.0
# 1             -6              -3.0        2121            SHOPPING     3.8
# 2              6               4.0        1824             MEDICAL     4.7
# 3             -6              -2.0        1567                GAME     4.6
# 4             12               4.0        2714     PERSONALIZATION     4.2
#
#     Reviews          Size    Installs  Type  Price Content Rating  \
# 0    2490.0  3.800000e+06    500000.0  Free    0.0   Everyone 10+
# 1   48732.0  2.000000e+07  10000000.0  Free    0.0       Everyone
# 2   23160.0  2.600000e+07   1000000.0  Free    0.0       Everyone
# 3  214878.0  1.000000e+07  10000000.0  Free    0.0       Everyone
# 4  115773.0  2.039287e+07  10000000.0  Free    0.0       Everyone
#
#              Genres Last Updated         Current Ver   Android Ver  \
# 0  Health & Fitness   2017-02-17                 1.9  2.3.3 and up
# 1          Shopping   2018-07-31               7.8.1    4.0 and up
# 2           Medical   2018-07-27               7.4.1    5.0 and up
# 3             Board   2018-08-03               2.0.4    4.1 and up
# 4   Personalization   2018-05-22  Varies with device    4.1 and up
#
#    Content Rating new
# 0                   2
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# ##### Top 5 apps

# %%
data_paid = data_merged['Type'] == 'Paid'
data_paid2 = data_merged[data_paid]
data_paid2.sort_values('afinn_sentiments',ascending=False).head(5)[['App','afinn_sentiments']]
# Out:
#                                 App  afinn_sentiments
# 371             Essential Anatomy 3              12.0
# 111                    BIG Launcher               6.0
# 147           Beautiful Widgets Pro               6.0
# 550                      HD Widgets               6.0
# 216  Call of Duty:Black Ops Zombies               3.0

# %% [markdown]
# ##### Lowest 5 apps

# %%
data_paid = data_merged['Type'] == 'Paid'
data_paid2 = data_merged[data_paid]
data_paid2.sort_values('afinn_sentiments',ascending=False).tail(5)[['App','afinn_sentiments']]
# Out:
#                                 App  afinn_sentiments
# 313         Diabetes & Diet Tracker              -4.0
# 412            Farming Simulator 18              -3.0
# 522         Golfshot Plus: Golf GPS               0.0
# 216  Call of Duty:Black Ops Zombies               3.0
# 111                    BIG Launcher               6.0

# %% [markdown]
# ### Wek4 Task4

# %%
data_paid = data_merged['Type'] == 'Paid'
data_paid2 = data_merged[data_paid]
data_paid2.sort_values('afinn_sentiments',ascending=False).head(5)[['App', 'Category', 'afinn_sentiments']]
# Out:
#                                 App         Category  afinn_sentiments
# 371             Essential Anatomy 3          MEDICAL              12.0
# 111                    BIG Launcher  PERSONALIZATION               6.0
# 147           Beautiful Widgets Pro  PERSONALIZATION               6.0
# 550                      HD Widgets  PERSONALIZATION               6.0
# 216  Call of Duty:Black Ops Zombies             GAME               3.0

# %%
data_paid = data_merged['Type'] == 'Paid'
data_paid2 = data_merged[data_paid]
data_paid2.groupby('Category')['afinn_sentiments'].mean()
# Out:
# Category
# GAME               0.0
# MEDICAL            4.0
# PERSONALIZATION    6.0
# SPORTS             0.0
# Name: afinn_sentiments, dtype: float64
